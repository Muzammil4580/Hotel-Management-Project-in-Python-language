# %%
import pandas as pd
import csv

######################################################## MAIN MENU START ######################################

print("\n\n*HOTEL MANAGMENT SYSTEM*\n")

def displayMain():
    while (1):
        print("1. Room Records")
        print("2. Customer Records")
        print("3. Exit")

        b = int(input("\nEnter the Number From menu To proceed:"))
        if (b == 1):
            print("\n\n*Room Record Management*\n")
            roomMgmt()
        if (b == 2):
            print("\n\n*Customer Record Management*\n")
            customerMgmt()
        if (b == 3):
            quit()
    return

######################################################## MAIN MENU END ######################################

######################################################## ROOM MANAGMENT START ###############################
######################################################## ROOM GOLBAL VARIABLE DEFINATION ####################

room_no = room_rate = 0
room_status = room_type = ""
hotel_rooms = {}

######################################################## ROOM MENU START ####################################

def roomMgmt():
    while (1):
        print("1. Add Room Record")
        print("2. Show All Room Records")
        print("3. Update Room Record")
        print("4. Delete Room Record")
        print("5. Exit to Main Menu")

        c = int(input("\nEnter the Number From menu To proceed:"))
        if (c == 1):
            print("\n\n*ADD ROOM RECORD*\n")
            if str(addRoom()):
                print("\n Room Added Success fully \n")
            else:
                print("\n Room Addition Failed \n")
        if (c == 2):
            print("\n\n*ALL ROOM RECORDS*\n")
            ShowAllRooms()
        if (c == 3):
            print("\n\n*UPDATE ROOM RECORD*\n")
            if updateRoom():
                print("\n Room Update Success fully \n")
            else:
                print("\n Room update Failed \n")
        if (c == 4):
            print("\n\n*DELETE ROOM RECORD*\n")
            if deleteRoom():
                print("\n Room deletion Failed \n")
            else:
                print("\n Room deleted Success fully \n")
        if (c == 5):
            break
    return

######################################################## ROOM MENU END ######################################

######################################################## ROOM FUNCTIONS START ###############################

def addRoom():
    with open('file.csv','rt') as f:
        data = csv.reader(f)
        for row in file:
            print
    #room_no = "Room # " + str(input("Enter Room No: "))
    #while (room_no in hotel_rooms):
        #room_no = "Room # " + str(input(room_no + " Already Exist, Enter other Room No. OR 0 to Return to Menu: "))
        #if room_no == "Room # 0":
            #return False
    #room_status = "Yes"
    #room_type = input("Enter Room Type Single or Double: ").title()
    #room_rate = input("Enter Room Rate per day in Rs.:")
    #hotel_rooms[room_no] = {"Status": room_status, "Type": room_type, "Rate": room_rate}
    #return room_no

def ShowAllRooms():
    room_nos = len(hotel_rooms)
    if (room_nos >= 1):
        print("\n Total No. of Rooms " + str(room_nos) + "\n")
        df = pd.DataFrame(hotel_rooms).T
        print(df)
        print("\n")
    else:
        print("\n Hotel is Empty \n")
    return

def ShowAvailableRooms():
    df = pd.DataFrame(hotel_rooms).T
    df = df.loc[(df.Status == "Yes")]
    if df.empty:
        print("No Room Available \n")
        return False
    else:
        print(df)
        print("\n")
    return True

def updateRoom():
    room_no = "Room # " + str(input("Enter Room No To Update: "))
    while (room_no not in hotel_rooms):
            room_no = "Room # " + str(input(room_no + " Does Not Exist, Enter other Room No. OR 0 to Return to Menu: "))
            if room_no == "Room # 0":
                return False
    hotel_rooms[room_no]['Status'] = input("Enter Room Availbility Yes or No: ").title()
    hotel_rooms[room_no]['Type'] = input("Enter Room Type Single or Double: ").title()
    hotel_rooms[room_no]['Rate'] = input("Enter Room Rate per day in Rs.:")
    return(room_no in hotel_rooms)

def deleteRoom():
    room_no = "Room # " + str(input("Enter Room No To Delete: "))
    while (room_no not in hotel_rooms):
            room_no = "Room # " + str(input(room_no + " Does Not Exist, Enter other Room No. OR 0 to Return to Menu: "))
            if room_no == "Room # 0":
                return False
    hotel_rooms.pop(room_no)
    return(room_no in hotel_rooms)

######################################################## ROOM FUNCTIONS END ###############################
######################################################## ROOM MANAGMENT END ###############################

######################################################## CUSTOMER MANAGMENT START ###############################
######################################################## CUSTOMER GOLBAL VARIABLE DEFINATION ####################

customer_no = customer_phone = 0
check_in = check_out = 0
customer_name = customer_address = ""
hotel_customers = {}

######################################################## CUSTOMER MENU START ####################################

def customerMgmt():
    while (1):
        print("1. Add Customer Record")
        print("2. Show All Customer Records")
        print("3. Update Customer Record")
        print("4. Delete Customer Record")
        print("5. Exit to Main Menu")

        c = int(input("\nEnter the Number From menu To proceed:"))
        if (c == 1):
            print("\n\n*ADD CUSTOMER RECORD*\n")
            if str(addCustomer()):
                print("\n Customer Added Success fully \n")
            else:
                print("\n Customer Addition Failed \n")
        if (c == 2):
            print("\n\n*ALL CUSTOMER RECORDS*\n")
            ShowAllCustomers()
        if (c == 3):
            print("\n\n*UPDATE CUSTOMER RECORD*\n")
            if updateCustomer():
                print("\n Customer Update Success fully \n")
            else:
                print("\n Customer update Failed \n")
        if (c == 4):
            print("\n\n*DELETE CUSTOMER RECORD*\n")
            if deleteCustomer():
                print("\n Customer deletion Failed \n")
            else:
                print("\n Customer deleted Success fully \n")
        if (c == 5):
            break
    return

######################################################## CUSTOMER MENU END ######################################

######################################################## CUSTOMER FUNCTIONS START ###############################

def addCustomer():
    customer_no = "Customer # " + str(input("Enter Customer No: "))
    while (customer_no in hotel_customers):
        customer_no = "Customer # " + str(input(customer_no + " Already Exist, Enter other Customer No. OR 0 to Return to Menu: "))
        if customer_no == "Customer # 0":
            return True
    customer_name = input("Enter Customer Name: ")
    customer_address = input("Enter Customer Address: ")
    customer_phone = input("Enter Customer Phone: ")
    check_in = input("Enter Check-In Date: ")
    check_out = input("Enter Check-Out Date: ")
    hotel_customers[customer_no] = {"Name": customer_name, "Address": customer_address, "Phone": customer_phone, "Check-In": check_in, "Check-Out": check_out}
    return customer_no

def ShowAllCustomers():
    customer_nos = len(hotel_customers)
    if (customer_nos >= 1):
        print("\n Total No. of Customers " + str(customer_nos) + "\n")
        df = pd.DataFrame(hotel_customers).T
        print(df)
        print("\n")
    else:
        print("\n Hotel is Empty - No Customer \n")
    return

def updateCustomer():
    customer_no = "Customer # " + str(input("Enter Customer No To Update: "))
    while (customer_no not in hotel_customers):
        customer_no = "Customer # " + str(input(customer_no + " Does Not Exist, Enter other Customer No. OR 0 to Return to Menu: "))
        if room_no == "Customer # 0":
            return True
    hotel_customers[customer_no]['Name'] = input("Enter Customer Name: ")
    hotel_customers[customer_no]['Address'] = input("Enter Customer Address: ")
    hotel_customers[customer_no]['Phone'] = input("Enter Customer Phone: ")
    hotel_customers[customer_no]['Check-In'] = input("Enter Customer Check-In Date: ")
    hotel_customers[customer_no]['Check-Out'] = input("Enter Customer Check-Out Date: ")
    return(customer_no in hotel_customers)

def deleteCustomer():
    customer_no = "Customer # " + str(input("Enter Customer No To Delete: "))
    while (customer_no not in hotel_customers):
            customer_no = "Customer # " + str(input(customer_no + " Does Not Exist, Enter other Customer No. OR 0 to Return to Menu: "))
            if customer_no == "Customer # 0":
                return True
    hotel_customers.pop(customer_no)
    return(customer_no in hotel_customers)

######################################################## CUSTOMER FUNCTIONS END ###############################
######################################################## CUSTOMER MANAGMENT END ###############################

######################################################## MAIN PROGRAM START ###################################

displayMain()

######################################################## MAIN PROGRAM END #####################################
# Out:
# *HOTEL MANAGMENT SYSTEM*
#
# 1. Room Records
# 2. Customer Records
# 3. Exit
#
# Enter the Number From menu To proceed:1
#
#
# *Room Record Management*
#
# 1. Add Room Record
# 2. Show All Room Records
# 3. Update Room Record
# 4. Delete Room Record
# 5. Exit to Main Menu
#
# Enter the Number From menu To proceed:1
#
#
# *ADD ROOM RECORD*
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\NASHRA~1\AppData\Local\Temp/ipykernel_13384/3686861885.py in <module>
#     233 ######################################################## MAIN PROGRAM START ###################################
#     234
# --> 235 displayMain()
#     236
#     237 ######################################################## MAIN PROGRAM END #####################################
#
# C:\Users\NASHRA~1\AppData\Local\Temp/ipykernel_13384/3686861885.py in displayMain()
#      15         if (b == 1):
# ...
